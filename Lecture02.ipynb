# %%
# Create Custom Loggings: It is the process of recording tracking data and events while an application runs. 
import logging
logging.basicConfig(level = logging.INFO,
                    filename = 'railway.log',
                    filemode = 'w',
                    format = '%(asctime)s - %(levelname)s - %(message)s',
                    force = True)

# %%
logging.info('Railone Application Started')

# %%
logging.info('Railone Application Terminated')

# %%
logging.info('Hello World')

# %%
# I work as senior sft developer for indian railway management,I want to design end to end application for indian railway reservation booking management system.The system design are as follows 1-streamlit as a fronted 2-python as a framework with sqlite3 as database to store and retrive entries on real time basis.for every transation or booking there will be loggs generated by the system.the code structure must be designed with orchestron modelling. :prepare professional prompt for me in order to degin the whole system as one application.
