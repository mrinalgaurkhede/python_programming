# %%
#Introduction to python programming
'''
Data Types
1.int: 01
2.float: 2.34
3.string: Any Text
4.bool: True/False
5.list: [1,1.22,'India',True,[23],(34),{}]
6.tuple: (1,1.22,'USA',True,[23],(34),{})
7.dict: {'Country':['USA','UAE']}
8.set: {}
9.None: 
---------------------------------------------
Data Structures
1.List: Mutable
2.Tuple: Immutable
3.Dictionary: Mutable
4.Sets: Mutable
------------------------------------------------
'''
print("Hello World")

name = 'Mrinal'
domain = 'DSDA'
experience = 15
#Formatted String
print(f'My name is {name} and domain {domain},having exp is {experience}')
# Out:
# Hello World
# My name is Mrinal and domain DSDA,having exp is 15

# %%
#Mathematical Operators
''' 
Addition +
Subtraction -
Multiplication *
Division /answers for floating
Double Division// whole number is an answer
Modulo %
'''

# %%
#Asking user to input the value
name = input('Enter the name:')
print(f"My name is {name}")
# Out:
# My name is Mrinal

# %%
age = input('Enter the age:')
print(type(age))
# Out:
# <class 'str'>

# %%
#Concept of Typecasting
age = int(input('Enter the age:'))
print(type(age))
# Out:
# <class 'int'>

# %%
#Example
num1 = 100
num2 = 200
num3 = '400'

print(num3*2)
# Out:
# 400400

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
modulo = num1 % num2

print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Modulo:", modulo)
# Out:
# Addition: 73.0
# Subtraction: 23.0
# Multiplication: 1200.0
# Modulo: 23.0
